# %%
import torch 

t = torch.Tensor(
    [[1,2,3], [4,5,6]]
)

# %%
# CDE - AB 

(7+8+10) + (6 + 8 + 7) / 6
# Out:
# 28.5

# %%
# Autoreload 
# %load_ext autoreload
# %autoreload 2
import pandas as pd 
import numpy as np

from pathlib import Path
from typing import Union, List, Tuple, Dict, Optional

# STFU
pd.options.mode.chained_assignment = None  # default='warn'
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
filename = "Hs_All_sample_2021.tsv"
# Load data
data = pd.read_csv(filename, sep="\t")
data
# Out:
#       search_batch_id                            experiment_tag  \
# 0                6195                                   raftapr
# 1                6196                                   raftaug
# 2                6197                                  raftflow
# 3                6198                           LNCALmicrosomal
# 4                6199                                 LNCALcyto
# ...               ...                                       ...
# 2322            11067                   kingdoms-of-life_Hs-U87
# 2323            11070               HEK293T_trypsin-Lysarginase
# 2324            11068                       HEK293T_Lysarginase
# 2325            11069  HEK293T_Lysarginase_N-terminalEnrichment
# 2326            11071        Cancer-CellLine-Encyclopedia_TMT10
#
#                                        sample_category  \
# 0                             Cancer Cell Lines, Blood
# 1                             Cancer Cell Lines, Blood
# 2                             Cancer Cell Lines, Blood
# 3     Cancer Cell Lines, Other Male Reproductive Organ
# 4     Cancer Cell Lines, Other Male Reproductive Organ
# ...                                                ...
# 2322                          Cancer Cell Lines, Brain
# 2323                             Non Cancer Cell Lines
# 2324                             Non Cancer Cell Lines
# 2325                             Non Cancer Cell Lines
# 2326      Cancer Cell Lines, Other Anatomical Entities
#
#                                        publication_name   pubmed_id  \
# 0     von Haller et al. 2003 Mol Cell Proteomics 2, ...  12832459.0
# 1     von Haller et al. 2003 Mol Cell Proteomics 2, ...  12832459.0
# 2     von Haller et al. 2003 Mol Cell Proteomics 2, ...  12832459.0
# 3     Lin et al. 2005, Cancer Res. 2005 Apr 15;65(8)...  15833837.0
# 4     Lin et al. 2005, Cancer Res. 2005 Apr 15;65(8)...  15833837.0
# ...                                                 ...         ...
# 2322                               Müller et al. (2020)  32555458.0
# 2323                                                NaN         NaN
# 2324                                                NaN         NaN
# 2325                                                NaN         NaN
# 2326                            Barretina et al. (2012)  22460905.0
#
#      repository_identifiers
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
# 2322              PXD019483
# 2323              PXD010551
# 2324              PXD010551
# 2325              PXD010551
# 2326                    NaN
#
# [2327 rows x 6 columns]
